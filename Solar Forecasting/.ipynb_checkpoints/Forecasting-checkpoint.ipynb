# %%
from matplotlib import pyplot as plt
from matplotlib.dates import MonthLocator, num2date
from matplotlib.ticker import FuncFormatter
from prophet import Prophet
from prophet.diagnostics import cross_validation, performance_metrics
from prophet.plot import add_changepoints_to_plot

import pandas as pd
import numpy as np
import datetime as dt
from collections import defaultdict
import time
import datetime as dt
from pytz import timezone
tz = timezone('EST')
from tqdm import tqdm

from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error

import seaborn as sns
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline
from matplotlib import pyplot as plt
from matplotlib import style
sns.set()

# %%
import json
from prophet.serialize import model_to_json, model_from_json

with open('nyc_solar_model.json', 'r') as fin:
    m = model_from_json(json.load(fin))  # Load model

# %%
future_pd = m.make_future_dataframe(
        periods=3650,
        freq='D',
        include_history=False
    )
    
# make predictions
forecast_pd = m.predict(future_pd)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10528/636448120.py in <module>
#       6
#       7 # make predictions
# ----> 8 forecast_pd = m.predict(future_pd)
#
# ~\anaconda3\lib\site-packages\prophet\forecaster.py in predict(self, df)
#    1208         seasonal_components = self.predict_seasonal_components(df)
#    1209         if self.uncertainty_samples:
# -> 1210             intervals = self.predict_uncertainty(df)
#    1211         else:
#    1212             intervals = None
#
# ~\anaconda3\lib\site-packages\prophet\forecaster.py in predict_uncertainty(self, df)
#    1439         Dataframe with uncertainty intervals.
#    1440         """
# -> 1441         sim_values = self.sample_posterior_predictive(df)
#    1442
#    1443         lower_p = 100 * (1.0 - self.interval_width) / 2
#
# ~\anaconda3\lib\site-packages\prophet\forecaster.py in sample_posterior_predictive(self, df)
#    1392         for i in range(n_iterations):
#    1393             for _j in range(samp_per_iter):
# -> 1394                 sim = self.sample_model(
#    1395                     df=df,
#    1396                     seasonal_features=seasonal_features,
#
# ~\anaconda3\lib\site-packages\prophet\forecaster.py in sample_model(self, df, seasonal_features, iteration, s_a, s_m)
#    1476
#    1477         sigma = self.params['sigma_obs'][iteration]
# -> 1478         noise = np.random.normal(0, sigma, df.shape[0]) * self.y_scale
#    1479
#    1480         return pd.DataFrame({
#
# KeyboardInterrupt:

# %%
forecast_pd

# %%
forecast_pd[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()

# %%
fig1 = m.plot(forecast_pd)

# %%
fig2 = m.plot_components(forecast_pd)

# %%
forecast_pd.to_csv('nyc_forecast.csv', index=False)
